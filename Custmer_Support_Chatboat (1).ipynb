# %%
import os
os.environ['GOOGLE_API_KEY'] = "AIzaSyAxOW028PXTtidc-_hn_mKfiooK06i58IA"

# %%
import os
import google.generativeai as genai
from PIL import Image

# Set your API key
os.environ['GOOGLE_API_KEY'] = "AIzaSyAxOW028PXTtidc-_hn_mKfiooK06i58IA"

genai.configure(api_key=os.environ['GOOGLE_API_KEY'])

def send_text_request(prompt):
    model = genai.GenerativeModel('gemini-pro')
    response = model.generate_content(prompt)
    return response.text

def image_analysis_request(image_path):
    model = genai.GenerativeModel('gemini-pro-vision')
    image = Image.open(image_path)
    response = model.generate_content(["Analyze the image", image])
    return response.text

if __name__ == '__main__':
    while True:
        user_input = input("You: ")
        if ' show image' in user_input.lower():
            image_path = input("Enter the path of the image file: ")
            output = image_analysis_request(image_path)
            print("Assistant:", output)
        else:
            output = send_text_request(user_input)
            print("Assistant:", output)
# Out:
# Assistant: ert ist der öffentlich-rechtliche Rundfunk in Griechenland.
# Assistant: As an AI chatbot, I don't have personal feelings or experiences, so I don't have a current emotional state. I am a language model designed to understand and respond to user queries and provide information to the best of my capabilities.
# Assistant: I am glad to hear that you are fine. Is there anything I can help you with today?
# Assistant: It is impossible for me to provide you with an accurate description of the day, as I do not have access to real-time information and my knowledge cutoff is April 2023.
#
# To obtain the most up-to-date information about the day, I recommend consulting a reliable news source or checking the local weather forecast.
# Assistant: **Warm-up (10 minutes)**
#
# * Light cardio: 5 minutes of jogging or cycling
# * Dynamic stretching: 10 repetitions of each exercise
#     * Arm circles
#     * Leg circles
#     * Torso twists
#
# **Strength training (30 minutes)**
#
# * **Compound exercises:**
#     * Squats: 3 sets of 10-12 repetitions
#     * Push-ups: 3 sets of 8-10 repetitions
#     * Romanian deadlifts: 3 sets of 10-12 repetitions
#     * Bench press: 3 sets of 8-10 repetitions
# * **Isolation exercises:**
#     * Bicep curls: 3 sets of 10-12 repetitions
#     * Tricep extensions: 3 sets of 10-12 repetitions
#     * Calf raises: 3 sets of 15-20 repetitions
#
# **Cool-down (10 minutes)**
#
# * Light cardio: 5 minutes of walking or jogging
# * Static stretching: Hold each stretch for 30 seconds
#     * Hamstring stretch
#     * Quad stretch
#     * Calf stretch
#
# **Tips:**
#
# * Choose weights that are challenging but allow you to maintain good form.
# * Focus on contracting the target muscles during each exercise.
# * Rest for 1-2 minutes between sets.
# * Drink plenty of water throughout the workout.
#
# **Note:** Adjust the number of sets, repetitions, and weight according to your fitness level. If you are new to strength training, start with a lighter weight and gradually increase the intensity over time.
# Assistant: **Artificial Intelligence Markup Language (AIML) Training**
#
# AIML is an XML-based language used to create and train chatbot systems. It provides a set of rules that define how the chatbot responds to user input. Training an AIML chatbot involves the following steps:
#
# **1. Create an AIML File:**
# Write an AIML file containing a collection of categories, patterns, and responses. Each category represents a topic or intention of the user, while patterns define the user input that triggers a specific response.
#
# **2. Define Patterns:**
# Create patterns that capture the different ways users might phrase their input. Patterns can use wildcards, pattern matching, and regular expressions to match a wide range of queries.
#
# **3. Provide Responses:**
# For each pattern, define a corresponding response. Responses can include text, HTML, XML, or other data formats. They can also contain AIML tags to perform actions or control the conversation.
#
# **4. Organize Categories:**
# Organize patterns and responses into categories based on the topics they represent. This helps the chatbot understand the context of the conversation and provide relevant responses.
#
# **5. Train the Chatbot:**
# Use an AIML interpreter or library to train the chatbot with the AIML file. The interpreter parses the file and creates an internal representation of the rules and responses.
#
# **6. Evaluate and Refine:**
# Test the chatbot with a variety of user inputs to evaluate its performance. Identify areas where the chatbot needs improvement and refine the AIML file accordingly.
#
# **Training Best Practices:**
#
# * **Use a Diverse Training Set:** Train the chatbot with a wide range of user inputs to cover different scenarios and variations in language.
# * **Identify Common Misspellings and Synonyms:** Include patterns that handle common misspellings and synonyms to ensure the chatbot can understand users' input accurately.
# * **Balance Specificity and Generality:** Create patterns that are specific enough to avoid ambiguity, but general enough to handle variations in user queries.
# * **Provide Clear and Concise Responses:** Write responses that are informative, helpful, and easy to understand.
# * **Implement Error Handling:** Define a fallback category or response to handle situations where the chatbot cannot find a matching pattern.
# * **Iterate and Refine:** Regularly test and evaluate the chatbot's performance, and make adjustments as needed to improve its accuracy and responsiveness.
# Assistant: ```
#                  ___------__
#              .-""       __---""-.
#         .---.,      ,-""            ""-.
#     .-"" --       /"                __.--'.
#    /      ___--""   .       __..-""        ""-.
#   /    .-'          /\_    .-'              "--.
#  /.-""             / / ""                      )
# /_..---.__.-""""""/ /                          '
#  `--/                \                         /
#     /                   )-.                   /
#     \          .-   .-'  \                 /
#      "-._ .-"   /  /      \               /
#         '--'   /-'        '.           .'
#              \_/          .'         .'
#                "-._       /         /
#                   '--.__.-'       .-"
#                     ""             |
#                                   |           .-'__
#                                   |          / /   '-.
#                                   |     .-   / /     ""-.
#                                   \    /    / /          `""-.
#                                    '"   /    / /              "".
#                                        '    '   / /                ""-.
#                                           .    / /                   "-._
#                                            |   / /                       "-._
#                                            |  / /                          ""-.
#                                            | / /                             "-._
#                                           / /                                 "-._
#                                          / /                                    "-._
#                                         / /                                       "-._
#                                        / /                                          "-._
#                                       / /                                             "-._
#                                      / /                                                "-._
#                                     / /                                                   "-._
#                                    / /                                                      "-._
#                                    `.'                                                         "-._
#                                      \                                                            "-._
#                                       |                                                               "-._
#                                      /     .                                                                 "-._
#                                     |     |                                                                   "-._
#                                     '-...-'                                                                     '-.
#                                       :                                                                       "-.
#                                        :""-.                                                              ""-.
#                                          """:-.                                                          ""-.
#                                             "":"".                                                       "".
#                                                """:-.                                                   "".
#                                                   """:-.                                              "".
#                                                     "":"".                                          "".
#                                                        """:-.                                     "".
#                                                           """:-.                            "".
#                                                              """:-.                      "".
#                                                                  """:-.                "".
#                                                                     """:-.          "".
#                                                                         """:.___..'""
# Assistant: <start_of_image>愛用翻訳者
# Assistant: <start_of_image>Version 1:
#
# [Image of a brown horse galloping through a field]
#
# Version 2:
#
# [Image of a white horse standing in a stable]
#
# Version 3:
#
# [Image of a black horse running in a race]
# Assistant: * [Unsplash](https://unsplash.com/search/photos/horse)
# * [Pexels](https://www.pexels.com/search/horse/)
# * [pixabay](https://pixabay.com/images/search/horse/)
# * [Getty Images](https://www.gettyimages.com/photos/horse)
# * [Shutterstock](https://www.shutterstock.com/search/horse)
# * [Adobe Stock](https://stock.adobe.com/search/horse)
# * [Canva](https://www.canva.com/photos/horse/)
# * [iStock](https://www.istockphoto.com/search/horse)
# * [Depositphotos](https://depositphotos.com/stock-photos/horse.html)
# * [123RF](https://www.123rf.com/stock-photo/horse.html)
# Assistant: ```python
# import random
#
# # Define the chatbot's responses
# responses = {
#     "greeting": ["Hello! How can I help you today?", "Hi there! What can I do for you?", "Welcome! What brings you here?"],
#     "thank_you": ["You're welcome!", "No problem!", "Happy to help!"],
#     "goodbye": ["Goodbye! Have a great day.", "See you later!", "Take care!"]
# }
#
# # Define the chatbot's knowledge base
# knowledge_base = {
#     "product_info": {
#         "product_a": {
#             "name": "Product A",
#             "price": 100,
#             "description": "This is a great product that does X, Y, and Z."
#         },
#         "product_b": {
#             "name": "Product B",
#             "price": 200,
#             "description": "This is a great product that does A, B, and C."
#         }
#     },
#     "order_status": {
#         "order_12345": {
#             "status": "shipped",
#             "tracking_number": "1234567890"
#         }
#     }
# }
#
# # Define the chatbot's main function
# def main():
#     # Print a greeting
#     print(random.choice(responses["greeting"]))
#
#     # Continuously loop until the user says goodbye
#     while True:
#         # Get the user's input
#         user_input = input()
#
#         # Check if the user said goodbye
#         if user_input.lower() in ["goodbye", "bye", "exit"]:
#             print(random.choice(responses["goodbye"]))
#             break
#
#         # Check if the user is asking for product information
#         elif user_input.lower().startswith("product"):
#             product_name = user_input.lower().split(" ")[1]
#             if product_name in knowledge_base["product_info"]:
#                 product_info = knowledge_base["product_info"][product_name]
#                 print(f"**Product Name:** {product_info['name']}")
#                 print(f"**Price:** {product_info['price']}")
#                 print(f"**Description:** {product_info['description']}")
#             else:
#                 print("Sorry, I don't have any information about that product.")
#
#         # Check if the user is asking for order status
#         elif user_input.lower().startswith("order"):
#             order_number = user_input.lower().split(" ")[1]
#             if order_number in knowledge_base["order_status"]:
#                 order_status = knowledge_base["order_status"][order_number]
#                 print(f"**Order Status:** {order_status['status']}")
#                 print(f"**Tracking Number:** {order_status['tracking_number']}")
#             else:
#                 print("Sorry, I don't have any information about that order.")
#
#         # Otherwise, give a generic response
#         else:
#             print("Sorry, I don't understand your question.")
#
# # Call the chatbot's main function
# if __name__ == "__main__":
#     main()
# ```
